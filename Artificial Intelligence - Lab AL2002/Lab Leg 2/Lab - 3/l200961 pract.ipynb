# %% [markdown]
# Write a Python program to find the length of a set, apply all sets
# operations(union,intersection) and print the results,find maximum and the minimum value in a
# set, remove all elements from a given set and find the length of a set.
#
# ```py
# set1 = {1,2,3,4,5}
# set2 = {4,5,6,7,8}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
# length of set
print('Length of set1',len(set1))
# union of set
print('Union of set1 and set2',set1.union(set2))
print('Union of set1 and set2 using \'|\'',set1 | set2)
# intersection of set
print('Intersection of set1 and set2',set1.intersection(set2))
print('Intersection of set1 and set2 using \'&\'',set1 & set2)
# difference of set
print('Difference of set1 and set2',set1.difference(set2))
print('Difference of set1 and set2 using \'-\'',set1 - set2)
# symmetric difference of set
print('Symmetric difference of set1 and set2',set1.symmetric_difference(set2))
print('Symmetric difference of set1 and set2 using \'^\'',set1 ^ set2)
# maximum and minimum of set
print('Maximum of set1',max(set1))
print('Minimum of set1',min(set1))
# remove all elements from set
set1.clear()
print('length of set1 after removing all elements',len(set1))
# Out:
# Length of set1 5
# Union of set1 and set2 {1, 2, 3, 4, 5, 6, 7, 8}
# Union of set1 and set2 using '|' {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection of set1 and set2 {4, 5}
# Intersection of set1 and set2 using '&' {4, 5}
# Difference of set1 and set2 {1, 2, 3}
# Difference of set1 and set2 using '-' {1, 2, 3}
# Symmetric difference of set1 and set2 {1, 2, 3, 6, 7, 8}
# Symmetric difference of set1 and set2 using '^' {1, 2, 3, 6, 7, 8}
# Maximum of set1 5
# Minimum of set1 1
# length of set1 after removing all elements 0

# %% [markdown]
# Write a program to count the number of vowels using sets in a given string.
# sample output
# ```py
# Input : Hello World
# Output : No. of vowels : 3

# %%
ins = input('Input: ')
# get number of vowels in input string
print('Number of vowels in input string',len(set(ins) & {'a','e','i','o','u'}))
# Out:
# Number of vowels in input string 2

# %% [markdown]
# Write a program to add, mul, divide two numbers x and y. Implement exception handling
# techniques (try..except clause) for handling possible exceptions in the scenario.

# %%
try:
    a,b = int(input('a: ')),int(input('b: '))
    print('a+b =',a+b)
    print('a*b =',a*b)
    print('a/b =',a/b)
except TypeError:
    print ('a and b should be of same type')
except ZeroDivisionError:
    print ('b should not be zero')
except ValueError:
    print ('a and b should be numbers')
else:
    print ('There may or may not have been an exception'
)
# Out:
# a+b = 1
# a*b = 0
# b should not be zero

# %% [markdown]
# Form a class queue and implement its functions using oop principles.

# %%
# class queue using all oop principles
class Queue:
    def __init__(self):
        self.queue = []
    def enqueue(self,element):
        self.queue.append(element)
    def dequeue(self):
        if len(self.queue) == 0:
            print('Queue is empty')
            return
        return self.queue.pop(0)
    def display(self):
        print('Queue:',self.queue)
    def size(self):
        return len(self.queue)  

q = Queue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.dequeue()
q.display()
print('Size of queue',q.size())
# Out:
# Queue: [2, 3]
# Size of queue 2

# %% [markdown]
# Form a queue using list data structure such that it works in LIFO order.

# %%
# queue using list works like lifo
q = []
q.append(1)
q.append(2)
q.remove(1)
print('Queue:',q)
# Out:
# Queue: [2]

# %% [markdown]
# Create a class for rectangle shape that calculates its area based upon the length and width

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width

r = Rectangle(2,3)
print('Area of rectangle',r.area())
# Out:
# Area of rectangle 6

# %% [markdown]
# Write a Python class named Circle constructed by a radius and two methods which will
# compute the area and the perimeter of a circle.

# %%
class Circle:
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius * self.radius
    def perimeter(self):
        return 2 * 3.14 * self.radius
    
c = Circle(2)
print('Area of circle',c.area())
print('Perimeter of circle',c.perimeter())
# Out:
# Area of circle 12.56
# Perimeter of circle 12.56
