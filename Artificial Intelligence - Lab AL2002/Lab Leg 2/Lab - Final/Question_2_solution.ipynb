# %%
import pandas as pd
from sklearn.cluster import KMeans

data = pd.read_csv("/content/kmeans dataset.csv")

# %%
data.head()
# Out:
#    data_point_A  data_point_B
# 0             5            10
# 1            15            20
# 2            25            30
# 3            35            40
# 4            45            50

# %%
data.shape
# Out:
# (5, 2)

# %%
centroids = [[15, 20], [35, 40]]

while True:
    for i, centroid in enumerate(centroids):
        column_name = f'Euclidean_distance_from_centroid_{i+1}'
        data[column_name] = euclidean_distances(data[['data_point_A', 'data_point_B']], [centroid])


    data['Assigned_Cluster'] = data[[f'Euclidean_distance_from_centroid_{i+1}' for i in range(len(centroids))]].idxmin(axis=1).str.extract('(\d+)')


    prev_centroids = centroids.copy()


    for i in range(len(centroids)):
        cluster_points = data[data['Assigned_Cluster'] == str(i + 1)][['data_point_A', 'data_point_B']]
        centroids[i] = cluster_points.mean().values.tolist()
        print(f"updated centroid------> {centroids[i]}")


    if prev_centroids == centroids:
        break


    print("Current Centroids:")
    for i, centroid in enumerate(centroids):
        print(f'Cluster {i+1}: {centroid}')


print("\nFinal Dataset with Assigned Clusters:")
print(data)
# Out:
# updated centroid------> [15.0, 20.0]
# updated centroid------> [40.0, 45.0]
# Current Centroids:
# Cluster 1: [15.0, 20.0]
# Cluster 2: [40.0, 45.0]
# updated centroid------> [15.0, 20.0]
# updated centroid------> [40.0, 45.0]
#
# Final Dataset with Assigned Clusters:
#    data_point_A  data_point_B  Euclidean_distance_from_centroid_1  \
# 0             5            10                           14.142136
# 1            15            20                            0.000000
# 2            25            30                           14.142136
# 3            35            40                           28.284271
# 4            45            50                           42.426407
#
#    Euclidean_distance_from_centroid_2 Assigned_Cluster
# 0                           49.497475                1
# 1                           35.355339                1
# 2                           21.213203                1
# 3                            7.071068                2
# ...

# %%
data.head()
# Out:
#    data_point_A  data_point_B  Euclidean_distance_from_centroid_1  \
# 0             5            10                           14.142136
# 1            15            20                            0.000000
# 2            25            30                           14.142136
# 3            35            40                           28.284271
# 4            45            50                           42.426407
#
#    Euclidean_distance_from_centroid_2 Assigned_Cluster
# 0                           49.497475                1
# 1                           35.355339                1
# 2                           21.213203                1
# 3                            7.071068                2
# 4                            7.071068                2
